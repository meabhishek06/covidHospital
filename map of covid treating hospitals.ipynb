# %%
import folium

# %%
import pandas as pd

# %%
dataset = pd.read_csv('hos.csv')

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 118 entries, 0 to 117
# Data columns (total 3 columns):
# Name         118 non-null object
# Latitude     118 non-null float64
# Longitude    118 non-null float64
# dtypes: float64(2), object(1)
# memory usage: 2.9+ KB

# %%
dataset.columns
# Out:
# Index(['Name', 'Latitude', 'Longitude'], dtype='object')

# %%
dataset.head(10)
# Out:
#                                                 Name   Latitude  Longitude
# 0      Ruby Hall Clinic Wanowrie, Maharashtra, India  18.485870  73.905853
# 1  Fortis Memorial Research Institute, Gurgaon, I...  28.456789  77.072472
# 2  Ahmedabad Civil Hospital, Ahmedabad, Gujarat, ...  23.053967  72.603844
# 3  Aakrithi Hospital, Vijayawada, Andhra Pradesh,...  16.511965  80.633163
# 4  VOC Port Trust Hospital, Muttayyapuram, Tamil ...   8.749402  78.168137
# 5              Vihar Hospital, Anand, Gujarat, India  22.554609  72.967361
# 6  Advanced Centre for Eyes, Kitchlu Nagar, Ludhi...  30.912411  75.819412
# 7  Delhi Heart Hospital, Jagriti Enclave, Anand V...  28.653229  77.308601
# 8  Nighasan Hospital, Nighasan, Uttar Pradesh, India  28.231674  80.862534
# 9              Apple Hospital, Surat, Gujarat, India  21.182947  72.831581

# %%
cpmap = folium.Map(location=[18.4,73.9], zoom_start=5)

# %%
dataset.columns
# Out:
# Index(['Name', 'Latitude', 'Longitude'], dtype='object')

# %%
dataset['Name'][0]
# Out:
# 'Ruby Hall Clinic Wanowrie, Maharashtra, India'

# %%
place = dataset[ ['Latitude', 'Longitude'] ]

# %%
type(place)
# Out:
# pandas.core.frame.DataFrame

# %%
# dataframe : numpy array : python list
place = place.values.tolist()

# %%
type(place)
# Out:
# list

# %%
def map(i,color):
    folium.Marker(
            location=point, 
            popup=dataset['Name'][i],
            icon=folium.Icon(color=color, icon='tint', icon_color='white' )
        ).add_to(cpmap)

# %%
i=0
for point in place:
    map(i,'red')
    i+=1

# %%
cpmap
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
cpmap.save('covidhostpitals.html')
